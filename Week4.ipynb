# %% [markdown]
# <a href="https://colab.research.google.com/github/bagasap10/COMP6577-MachineLearning/blob/main/Week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('https://raw.githubusercontent.com/andrychowanda/COMP6577/master/listings.csv')

# %% [markdown]
# # Probability Density Function (PDF)

# %% [markdown]
# In probability theory, a probability density function (PDF), or density of a continuous random variable, is a function that describes the relative likelihood for this random variable to take on a given value.

# %% [markdown]
# **Kernel Density Estimation**
#
# kernel density estimation is a non-parametric way to estimate the probability density function of a random variable.

# %%
plt.figure(figsize=(15,10))

subject = ['longitude','latitude','availability_365','number_of_reviews','reviews_per_month','price','minimum_nights','calculated_host_listings_count']

for i in range(1,8):
  plt.subplot(2,4,i)
  sns.histplot(data[subject[i-1]], kde=True)
